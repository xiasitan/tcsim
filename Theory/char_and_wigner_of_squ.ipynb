# %%
from qutip import*
from tcsim.visualization import plot_char, plot_wigner

# %%
N = 50
state = ((displace(N,2) )*squeeze(N,0.7)*fock(N,0)).unit()

# %%
plot_wigner(state)

# %%
plot_char(tensor(fock(N,0),state), max_alpha = 6)
