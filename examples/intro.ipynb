# %%
from tcsim.system import*
from tcsim.visualization import*
from tcsim.gates import*

# %%
# values such result in ECD(1)
t_displace = np.linspace(0,0.03,10)
t_wait = np.linspace(0,0.1,10)
epsilon = 64

# %%
state = U(vac, t_displace, t_wait, 1, epsilon)

# %%
plot_wigner(state)

# %%
plot_char(state)

# %%
plot_char_exp(state, t_displace, t_wait, epsilon)

# %%
loss = calc_loss(1000,1000,5,5)
plot_char_exp(state, t_displace, t_wait, epsilon, loss = loss)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jonat\Desktop\Coding\tcsim\Examples\intro.ipynb Cell 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jonat/Desktop/Coding/tcsim/Examples/intro.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> loss = calc_loss(1000,1000,5,5)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jonat/Desktop/Coding/tcsim/Examples/intro.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> plot_char_exp(state, t_displace, t_wait, epsilon, loss = loss)
#
# File ~\Desktop\Coding\tcsim\tcsim\visualization.py:191, in plot_char_exp(state, t_displace, t_wait, epsilon, chi, loss, max_alpha, npts, real, fig, ax)
#     174 def plot_char_exp(
#     175     state,
#     176     t_displace,
#    (...)
#     186
#     187 ):
#     189     xvec = np.linspace(-max_alpha, max_alpha, npts)
# ...

# %%
16.2-7.2
# Out:
# 9.0
